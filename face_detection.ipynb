# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
# Load our image then convert it to grayscale
image = cv2.imread('image/david_beckham.jpg')
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.title('Input Image')
cv2.imwrite('image/input_image.jpg', image)

plt.show()

# %%
# We point OpenCV's CascadeClassifier function to where our 
# classifier (XML file format) is stored
face_classifier = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

# Our classifier returns the ROI of the detected face as a tuple
# It stores the top left coordinate and the bottom right coordiantes
faces = face_classifier.detectMultiScale(gray, 1.3, 5)

# When no faces detected, face_classifier returns and empty tuple
if faces is ():
    print("No faces found")

# We iterate through our faces array and draw a rectangle
# over each face in faces
for (x,y,w,h) in faces:
    cv2.rectangle(image, (x,y), (x+w,y+h), (127,0,255), 2)
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.title('Face Detection')
    cv2.imwrite('image/face_detection.jpg', image); plt.show()
# Out:
# <>:10: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:10: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /var/folders/4w/3pzskng954b6kbypnlq6q7_h0000gn/T/ipykernel_67275/2135684322.py:10: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if faces is ():
